# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
val = pd.read_csv('data_for_project_val-train/val.csv', header = 0)
val.head()
# Out:
#    BAD   LOAN   MORTDUE     VALUE   REASON      JOB  YOJ  DEROG  DELINQ  \
# 0    0  21900   61838.0   92091.0  DebtCon   Office  5.0    NaN     NaN
# 1    0  21900  148955.0  118862.0      NaN  ProfExe  6.0    0.0     0.0
# 2    0  21900       NaN   57036.0  DebtCon    Other  NaN    0.0     0.0
# 3    0  21900   94320.0  140698.0  DebtCon  ProfExe  NaN    0.0     0.0
# 4    0  21900  105787.0  142466.0  HomeImp  ProfExe  8.0    0.0     0.0
#
#         CLAGE  NINQ  CLNO    DEBTINC
# 0  171.576700   NaN  16.0  37.800401
# 1   93.925882   3.0  34.0  30.322115
# 2  308.603445   0.0  18.0  39.234608
# 3  208.241758   0.0  20.0  29.188980
# 4  145.377177   0.0  22.0  32.333899

# %%
val.iloc[150:235, :1]
# Out:
#      BAD
# 150    0
# 151    0
# 152    0
# 153    0
# 154    0
# ..   ...
# 230    0
# 231    0
# 232    0
# 233    0
# 234    0
#
# [85 rows x 1 columns]

# %%
{
  "prediction": [
    0,
    1,
    1,
    0,
    0,
    0,
    0,
    0,
    1,
    0,
    1
  ]
}
# Out:
# {'prediction': [0, 1, 1, 0, 0, 0, 0, 0, 1, 0, 1]}

# %%
val = val.drop(['BAD'], axis=1)

# %%
val = val.iloc[150:235,:]

# %%
v = val.to_json()

# %%
v
# Out:
# '{"LOAN":{"150":22700,"151":22700,"152":22700,"153":22700,"154":22700,"155":22700,"156":22700,"157":22700,"158":22700,"159":22700,"160":22700,"161":22700,"162":22700,"163":22700,"164":22800,"165":22800,"166":22800,"167":22800,"168":22800,"169":22800,"170":22800,"171":22800,"172":22800,"173":22800,"174":22800,"175":22800,"176":22800,"177":22800,"178":22800,"179":22800,"180":22800,"181":22800,"182":22900,"183":22900,"184":22900,"185":22900,"186":22900,"187":22900,"188":22900,"189":22900,"190":22900,"191":22900,"192":22900,"193":22900,"194":22900,"195":22900,"196":22900,"197":22900,"198":22900,"199":22900,"200":22900,"201":22900,"202":22900,"203":22900,"204":22900,"205":23000,"206":23000,"207":23000,"208":23000,"209":23000,"210":23000,"211":23000,"212":23000,"213":23000,"214":23000,"215":23000,"216":23000,"217":23000,"218":23000,"219":23000,"220":23000,"221":23000,"222":23000,"223":23000,"224":23000,"225":23000,"226":23000,"227":23000,"228":23000,"229":23000,"230":23100,"231":23100,"232
# ...
